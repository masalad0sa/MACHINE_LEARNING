# %% [markdown]
# <a href="https://colab.research.google.com/github/masalad0sa/MACHINE_LEARNING/blob/main/Practical_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

iris = load_iris()
X = iris.data
y = iris.target
feature_names = iris.feature_names
print("Initial Shape of our Dataset", X.shape)
# Out:
# Initial Shape of our Dataset (150, 4)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
cov_matrix = np.cov(X_scaled.T)
print("Covariance matrix shape:", cov_matrix.shape)
# Out:
# Covariance matrix shape: (4, 4)

# %%
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

print("Eigenvalues:\n", eigenvalues)
print("\nEigenvectors shape:", eigenvectors.shape)
# Out:
# Eigenvalues:
#  [2.93808505 0.9201649  0.14774182 0.02085386]
#
# Eigenvectors shape: (4, 4)

# %%
sorted_index = np.argsort(eigenvalues)[::-1]
sorted_eigenvalues = eigenvalues[sorted_index]
sorted_eigenvectors = eigenvectors[:, sorted_index]

# %%
explained_variance_ratio = sorted_eigenvalues / np.sum(sorted_eigenvalues)

print("\nExplained Variance Ratio:")
for i, var in enumerate(explained_variance_ratio):
    print(f"PC{i+1}: {var:.4f}")
# Out:
# Explained Variance Ratio:
# PC1: 0.7296
# PC2: 0.2285
# PC3: 0.0367
# PC4: 0.0052

# %%
top_k_eigenvectors = sorted_eigenvectors[:, :k]

X_reduced = np.dot(X_scaled, top_k_eigenvectors)

print("\nReduced Dataset Shape:", X_reduced.shape)
# Out:
# Reduced Dataset Shape: (150, 2)
